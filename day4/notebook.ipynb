# %% [markdown]
# Day 4: Pre-processing Techniques
#
# Filling missing values with the mean is better than using 0 because:
#
# - 0 is not a realistic value for age and can mislead the model
# - Mean maintains the overall distribution of data
# - It helps the model learn patterns more accurately

# %%
df_fill = df.fillna(df.mean())

df_drop, df_fill
# Out:
# (    Age  Score
#  0  21.0   80.0
#  3  24.0   95.0,
#           Age      Score
#  0  21.000000  80.000000
#  1  22.666667  75.000000
#  2  23.000000  83.333333
#  3  24.000000  95.000000)

# %%
df_drop = df.dropna()

# %%
import pandas as pd

data = {
    'Age': [21, None, 23, 24],
    'Score': [80, 75, None, 95]
}

df = pd.DataFrame(data)
df
# Out:
#     Age  Score
# 0  21.0   80.0
# 1   NaN   75.0
# 2  23.0    NaN
# 3  24.0   95.0
